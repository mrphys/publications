# %%
from fetch_pubmed_utils import *

df = pd.read_csv('UCL_ICS.csv')
departments = df['department'].unique()
content_path = 'content'



# Base configuration
config = {
    "baseURL": "https://ti-yao.github.io/publications/",
    "title": "Institute of Cardiovascular Science",
    "menu": {"main": []},
    "params": {
        "description": "",
        "img_home": "img/publications.jpg",
        "img_404": "img/404.jpg"
    }
}


# Generate department pages
for department in departments[:]:
    department_df = df[df['department'] == department]
    department_url = department_df['department_url'].values[0]

    for group, group_url, authors_list in department_df[['group','group_url','authors']].values:
        print(group, group_url)
        authors_list = [name.strip() for name in authors_list.split(',')]
        create_pubs(authors_list, group_url)


    # Department folder
    dept_path = f'{content_path}/{department_url}'
    md_content = {
        "title": department,
        "draft": False,
        "layout": "department",
        "header_img": "img/publications.jpg",
        "subtitle": ' | '.join(department_df['group'].tolist())
    }
    write_yaml(f"{dept_path}/_index.md", md_content)

    # Generate group pages within the department
    for group, group_url, authors in department_df[['group','group_url','authors']].values:
        group_path = f'{dept_path}/{group_url}'
        pubs_df = pd.read_json(f"data/pubs_{group_url}.json")

        md_content = {
            "title": group,
            "date": "2024-10-18T17:04:07+01:00",
            "draft": False,
            "layout": "publication",
            "header_img": "img/publications.jpg",
            "file": f"data/pubs_{group_url}.json",
            "department_url": department_url,
            "department": department,
            # "subtitle": f'Number of Publications = {len(pubs_df)}'
        }
        write_yaml(f"{group_path}/_index.md", md_content)

        # Add group to config menu
        config["menu"]["main"].append({
            "identifier": group_url,
            "name": group,
            "url": f'/{department_url}/{group_url}'
        })

# Write configuration file
write_yaml("config.yaml", config)
# Out:
# The Hatter Cardiovascular Institute  hatter
# Processing author: Derek M Yellon
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# ...
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# /home/tina/Documents/Website/publications/fetch_pubmed_utils.py:100: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df['Affiliation'].astype(str).str.contains(affil_pattern, regex=True, na=False)
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/tina/miniconda3/envs/py3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_384164/3526120125.py", line 30, in <module>
#     create_pubs(authors_list, group_url)
#   File "/home/tina/Documents/Website/publications/fetch_pubmed_utils.py", line 182, in create_pubs
#   File "/home/tina/miniconda3/envs/py3/lib/python3.10/site-packages/pandas/core/generic.py", line 6643, in astype
#     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#   File "/home/tina/miniconda3/envs/py3/lib/python3.10/site-packages/pandas/core/internals/managers.py", line 430, in astype
#     return self.apply(
#   File "/home/tina/miniconda3/envs/py3/lib/python3.10/site-packages/pandas/core/internals/managers.py", line 363, in apply
#     applied = getattr(b, f)(**kwargs)
#   File "/home/tina/miniconda3/envs/py3/lib/python3.10/site-packages/pandas/core/internals/blocks.py", line 758, in astype
#     new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#   File "/home/tina/miniconda3/envs/py3/lib/python3.10/site-packages/pandas/core/dtypes/astype.py", line 237, in astype_array_safe
#     new_values = astype_array(values, dtype, copy=copy)
#   File "/home/tina/miniconda3/envs/py3/lib/python3.10/site-packages/pandas/core/dtypes/astype.py", line 182, in astype_array
#     values = _astype_nansafe(values, dtype, copy=copy)
#   File "/home/tina/miniconda3/envs/py3/lib/python3.10/site-packages/pandas/core/dtypes/astype.py", line 133, in _astype_nansafe
#     return arr.astype(dtype, copy=True)
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/tina/miniconda3/envs/py3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2120, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/home/tina/miniconda3/envs/py3/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/tina/miniconda3/envs/py3/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/tina/miniconda3/envs/py3/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/home/tina/miniconda3/envs/py3/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1088, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#   File "/home/tina/miniconda3/envs/py3/lib/python3.10/site-packages/IPython/core/ultratb.py", line 970, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#   File "/home/tina/miniconda3/envs/py3/lib/python3.10/site-packages/IPython/core/ultratb.py", line 792, in lines
#     return self._sd.lines
#   File "/home/tina/miniconda3/envs/py3/lib/python3.10/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/tina/miniconda3/envs/py3/lib/python3.10/site-packages/stack_data/core.py", line 734, in lines
#     pieces = self.included_pieces
#   File "/home/tina/miniconda3/envs/py3/lib/python3.10/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/tina/miniconda3/envs/py3/lib/python3.10/site-packages/stack_data/core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/home/tina/miniconda3/envs/py3/lib/python3.10/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/tina/miniconda3/envs/py3/lib/python3.10/site-packages/stack_data/core.py", line 660, in executing_piece
#     return only(
#   File "/home/tina/miniconda3/envs/py3/lib/python3.10/site-packages/executing/executing.py", line 116, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0
