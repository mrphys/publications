# %%
from fetch_pubmed_utils import *

df = pd.read_csv('UCL_ICS.csv')
departments = df['department'].unique()
content_path = 'content'



# Base configuration
config = {
    "baseURL": "https://ti-yao.github.io/publications/",
    "title": "Institute of Cardiovascular Science",
    "menu": {"main": []},
    "params": {
        "description": "",
        "img_home": "img/publications.jpg",
        "img_404": "img/404.jpg"
    }
}


# Generate department pages
for department in departments[:]:
    department_df = df[df['department'] == department]
    department_url = department_df['department_url'].values[0]

    for group, group_url, authors_list in department_df[['group','group_url','authors']].values:
        print(group, group_url)
        authors_list = [name.strip() for name in authors_list.split(',')]
        create_pubs(authors_list, group_url)


    # Department folder
    dept_path = f'{content_path}/{department_url}'
    md_content = {
        "title": department,
        "draft": False,
        "layout": "department",
        "header_img": "img/publications.jpg",
        "subtitle": ' | '.join(department_df['group'].tolist())
    }
    write_yaml(f"{dept_path}/_index.md", md_content)

    # Generate group pages within the department
    for group, group_url, authors in department_df[['group','group_url','authors']].values:
        group_path = f'{dept_path}/{group_url}'
        pubs_df = pd.read_json(f"data/pubs_{group_url}.json")

        md_content = {
            "title": group,
            "date": "2024-10-18T17:04:07+01:00",
            "draft": False,
            "layout": "publication",
            "header_img": "img/publications.jpg",
            "file": f"data/pubs_{group_url}.json",
            "department_url": department_url,
            "department": department,
            # "subtitle": f'Number of Publications = {len(pubs_df)}'
        }
        write_yaml(f"{group_path}/_index.md", md_content)

        # Add group to config menu
        config["menu"]["main"].append({
            "identifier": group_url,
            "name": group,
            "url": f'/{department_url}/{group_url}'
        })

# Write configuration file
write_yaml("config.yaml", config)
# Out:
# The Hatter Cardiovascular Institute  hatter
# Processing author: Derek M Yellon
# Processing author: Malcolm Walker
# Processing author: Robert Bell
# Processing author: Sean M Davidson
# Cardiovascular Surgery  surgery
# Processing author: Christopher Mcgregor
# Processing author: Guerard Byrne
# Processing author: Gaetano Burriesci
# Processing author: Jacob Salmonsmith
# Processing author: Benjamin Rahmani
# Processing author: Romilde Kotze
# No IDs found for Romilde Kotze
# Cardiovascular Physiology and Pharmacology  pharmacology
# Processing author: Lucie Clapp
# Processing author: Jigisha Patel
# Processing author: Nelson Orie
# Frankel Lab frankel
# Processing author: Paul Frankel
# Functional Gene Annotation  gene
# Processing author: Ruth Lovering
# Molecular Biology Development and Disease  biology
# Processing author: Vishwanie Budhram-Mahadeo
# Centre for Translational Genomics   genomics
# Processing author: Riyaz Patel
# Processing author: Folkert Asselbergs
# Processing author: Tom Lumbers
# Processing author: Floriaan Schmidt
# Unit for Lifelong Health and Ageing ageing
# Processing author: Nishi Chaturvedi
# Processing author: Sophie Eastwood
# Multimorbidity Mechanisms and Therapeutics Research Collaborative multimorbidity
# Processing author: Aroon Hingorani
# Processing author: Chris Finan
# Bloomsbury Centre for Clinical Phenotyping  phenotyping
# Processing author: Alun Hughes
# Processing author: Scott Chiesa
# Processing author: Gaby Captur
# Centre for Heart Muscle Disease muscle
# Processing author: Perry Elliott
# Processing author: Luis Lopes
# Processing author: Petros Syrris
# Centre for Translational Electrophysiology and Data Science electrophysiology
# Processing author: Pier Lambiase
# Processing author: Peter Taggart
# Processing author: Michele Orini
# Processing author: Stefan Van Duijvenboden
# Processing author: Claire Martin
# Processing author: Richard Ang
# Centre for Cardiovascular Disease Imaging imaging
# Processing author: James Moon
# Processing author: Charlotte Manisty
# Processing author: Guy Lloyd
# Processing author: Christos Bourantas
# Processing author: Thomas Treibel
# Processing author: Rhodri Davies
# Translational Cardiovascular Imaging translational
# Processing author: Vivek Muthurangu
# Processing author: Jennifer Steeden
# Processing author: Michael Quail
# Processing author: Daniel Knight
# Outcomes in Paediatric Critical Illness and Cardiovascular Disease outcomes
# Processing author: Katherine Brown
# Processing author: Joanna Wray
# Processing author: Victor Tsang
# Processing author: Aparna Hoskote
# Paediatric Inherited and Rare Cardiovascular Disease disease
# Processing author: Juan Pablo Kaski
# Processing author: Gabrielle Norrish
# Processing author: Shahin Moledina
# Heart Failure, Transplantation and Extracorporeal Support support
# Processing author: Michael Burch
# Processing author: Richard Issitt
# Processing author: Matthew Fenton
# Processing author: Timothy Thiruchelvam
# Processing author: Jacob Simmonds
# Morphology and Structural Heart Disease morphology
# Processing author: Andrew Cook
# Processing author: Martin Kostolny
# Processing author: Adrian Crucean
# Clinical Cardiovascular Engineering engineering
# Processing author: Silvia Schievano
# Processing author: Claudio Capelli
# Processing author: Andrew Taylor
